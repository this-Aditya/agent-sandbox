# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os

load_dotenv(override=True)
# Out:
# True

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

model = init_chat_model(
    model="arc:lite",
    model_provider="openai",
    base_url=os.getenv("RADAR_OPEN_MODEL_BASE_URL"),
    api_key=os.getenv("RADAR_OPEN_MODEL_API_KEY"),
)

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)
print(response)

print("\n")
print(response['messages'][1].content)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the moon?", additional_kwargs={}, response_metadata={}, id='642ae3dd-8e69-40d1-af44-8b4c85c11417'), AIMessage(content='The Moon does not have a capital because it is not a country or a political entity; it is a natural satellite of Earth with no government, population, or permanent settlements.\n\nHowever, in the realms of **science fiction** and **pop culture**, various fictional "capitals" have been established:\n\n*   **Luna City:** A common trope name used in various sci-fi stories.\n*   **Armstrong City:** Often used in speculative fiction to honor Neil Armstrong.\n*   **Artemis Base:** Frequently used in modern sci-fi to reflect NASA\'s current Artemis program.\n\nIf you are looking for the most "important" location on the Moon currently, scientists focus on the **Lunar South Pole**, because it contains water ice which is critical for future human colonization.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 22, 'total_tokens': 184, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'arc:lite', 'system_fingerprint': 'vllm-0.23.0-406383e7', 'id': 'chatcmpl-8a647efd85058dde', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f5b3f-9930-7b82-bb5c-2a6b7014690e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 162, 'total_tokens': 184, 'input_token_details': {}, 'output_token_details': {}})]}
#
#
# The Moon does not have a capital because it is not a country or a political entity; it is a natural satellite of Earth with no government, population, or permanent settlements.
#
# However, in the realms of **science fiction** and **pop culture**, various fictional "capitals" have been established:
#
# *   **Luna City:** A common trope name used in various sci-fi stories.
# *   **Armstrong City:** Often used in speculative fiction to honor Neil Armstrong.
# *   **Artemis Base:** Frequently used in modern sci-fi to reflect NASA's current Artemis program.
#
# If you are looking for the most "important" location on the Moon currently, scientists focus on the **Lunar South Pole**, because it contains water ice which is critical for future human colonization.

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Since the moon does not currently have a capital, I will construct one for you.
#
# In the year 2144, the political and economic heart of the lunar surface is not a sprawling metropolis of glass domes, but a subterranean masterpiece of engineering known as **Selene’s Reach**.
#
# ***
#
# ### **The Capital City: Selene’s Reach**
#
# **The Concept: "The Vertical Spire"**
# Because the lunar surface is a lethal environment of radiation and micro-meteoroids, the capital was not built *on* the moon, but *into* it. Selene’s Reach is located within the depths of the **Aristarchus Crater**. Instead of wide streets, the city is a massive, vertical cylinder carved into the lunar basalt, descending three kilometers into the crust.
#
# **The Architecture: The Gravity-Wells**
# The city is organized into concentric rings around a central hollow core known as **The Shaft**.
# *   **The Zenith Rings (Upper Levels):** These are the high-luxury sectors. Here, the ceilings are massive, reinforced transparent aluminum viewing ports that look up at the Earth hanging perpetually in the black sky. The gravity is slightly boosted by centrifugal rotation to mimic a comfortable 0.8g, making the residents feel "lighter" and more elegant.
# *   **The Meridian Districts (Middle Levels):** The industrial and administrative heart. This is where the Lunar High Council meets in the *Obsidian Chamber*. The architecture here is brutalist and functional—polished gray stone, neon-blue lighting, and high-speed mag-lev elevators.
# *   **The Abyssal Docks (Lower Levels):** The lowest, most pressurized level of the city. This is where the massive ore-freighters and helium-3 tankers dock. It is a gritty, humid, and bustling place, filled with the smell of recycled oxygen and the constant vibration of heavy machinery.
#
# **The Atmosphere: "The Eternal Twilight"**
# Because there is no natural sunlight inside the crater, the city uses a sophisticated "Light-Cycle" system. The central shaft is lined with massive LED arrays that mimic a 24-hour Earth cycle. In the "morning," the light is a soft amber; by "noon," it is a brilliant white; and by "evening," it fades to a deep violet. This prevents the psychological "Lunar Melancholy" that plagues long-term settlers.
#
# **The Economy: The Helium-3 Standard**
# Selene’s Reach is the wealthiest city in the solar system because it controls the flow of Helium-3, the fuel that powers the fusion reactors of Earth and the Mars colonies. The city’s central bank, the **Lunar Exchange**, dictates the value of energy across the inner planets.
#
# **A Local Legend: The "Dust-Walkers"**
# Among the citizens, there is a whispered subculture of "Dust-Walkers"—outcasts who refuse to live in the pressurized comfort of the Rings. They live in the unmapped, pressurized lava tubes surrounding the city, surviving on scavenged tech and moving through the lunar regolith like ghosts in the dark.
#
# ***
#
# **Would you like to know more about the government of Selene's Reach, or perhaps a specific district within the city?**

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# **Lunara**
#
# Perched at the edge of the Mare Tranquillitatis, where ancient lava plains meet the shimmering rim of the Shackleton Crater, *Lunara* is the moon’s first true city—a crystalline metropolis woven into the lunar regolith and bathed in the soft, eternal glow of Earthlight.
#
# Built beneath a geodesic dome of self-repairing photonic glass, Lunara pulses with bioluminescent veins of algae-fueled lighting and gravity-simulating rings that keep its citizens grounded in a world where a single misstep could send them floating into the stars. The city’s skyline is a forest of vertical farms, solar-sails, and magnetic sky-lanes where autonomous pods glide silently between orbital platforms.
#
# At its heart lies the *Astral Spire*, a towering observatory that doubles as a quantum communications hub, linking Earth, Mars, and the asteroid belt. From its observation decks, visitors gaze upon the blue marble of Earth—our cradle—now a distant, serene jewel in the velvet black.
#
# Lunara is not just a capital—it’s a symbol: humanity’s quiet foothold in the cosmos, where the silence of the moon is broken only by the hum of innovation, the whisper of recycled air, and the dream of a future written in starlight.
#
# Welcome to **Lunara**—the Moon’s heartbeat.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: Selene Prime
# Location: Permanently shadowed crater rim near the Moon’s south pole, nestled within a network of pressurized domes and subterranean tunnels carved into basaltic bedrock
# Vibe: Futuristic, serene, isolated
# Economy: Lunar helium-3 mining, zero-gravity manufacturing, deep-space research hubs, and high-precision astrophysics observatories

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel



class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str



agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      10     vibe: str
#      11     economy: str
#      14 agent = create_agent(
# ---> 15     model=model,
#      16     system_prompt="You are a science fiction writer, create a capital city at the users request.",
#      17     response_format=CapitalInfo
#      18 )
#      20 question = HumanMessage(content="What is the capital of The Moon?")
#      22 response = agent.invoke(
#      23     {"messages": [question]}
#      24 )
#
# NameError: name 'model' is not defined

# %%
response["structured_response"].name

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
