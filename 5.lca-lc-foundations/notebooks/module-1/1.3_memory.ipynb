# %%
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent

model = init_chat_model(
    model="qwen3-30b",
    model_provider= "openai",
    base_url=os.getenv("RADAR_OPEN_MODEL_BASE_URL"),
    api_key=os.getenv("RADAR_OPEN_MODEL_API_KEY")
)
agent = create_agent(
    model=model,
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='62358e62-d12b-4b9d-91c8-5cbbb2a154ab'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a wonderful choice—great for nature, calmness, and fresh beginnings! 🌿 Is there something special about green that you love, or do you just think it's the most vibrant color? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 20, 'total_tokens': 76, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3-30b', 'system_fingerprint': 'vllm-0.22.1-a8343ffa', 'id': 'chatcmpl-b2582ea555615647', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4cfa-fcfb-78e0-b3e9-a450f388a01d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 56, 'total_tokens': 76, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='42c12f55-e409-4801-9aea-7b74123d1f85'),
#               AIMessage(content="I don't know your favorite color yet! 😊 But I'd love to find out — do you have one you especially like? 🌈", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 14, 'total_tokens': 45, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3-30b', 'system_fingerprint': 'vllm-0.22.1-a8343ffa', 'id': 'chatcmpl-8b0a0282eaee86fd', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4cfb-6240-74c3-9662-c5626aa64490-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 31, 'total_tokens': 45, 'input_token_details': {}, 'output_token_details': {}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    model=model,
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='e1b8fda4-0032-4e34-9075-d596ba94b733'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a wonderful choice—such a vibrant and refreshing colour! It’s often associated with nature, growth, and harmony. Do you have a special reason why green is your favourite? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 20, 'total_tokens': 71, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3-30b', 'system_fingerprint': 'vllm-0.22.1-a8343ffa', 'id': 'chatcmpl-9f4d223f5026065f', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4cfc-282a-72a3-8667-e2e2d7014092-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 51, 'total_tokens': 71, 'input_token_details': {}, 'output_token_details': {}}),
#               HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='bd44d655-cd48-4fc0-b0dd-90ae532047e0'),
#               AIMessage(content="Hello Seán! 👋 It's great to meet you again—welcome back! Green is a fantastic choice—full of life, calm, and connection to nature. Whether it’s the lushness of forests, the freshness of spring, or even a favourite shirt or team jersey, green has a special way of standing out. Is there a particular shade of green you love most? 🌿💚", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 92, 'total_tokens': 174, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3-30b', 'system_fingerprint': 'vllm-0.22.1-a8343ffa', 'id': 'chatcmpl-ae374513e7e056af', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4d05-76cb-7912-9e06-4f79b5481641-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 92, 'output_tokens': 82, 'total_tokens': 174, 'input_token_details': {}, 'output_token_details': {}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='e1b8fda4-0032-4e34-9075-d596ba94b733'),
#               AIMessage(content="Hello Seán! It's nice to meet you. Green is a wonderful choice—such a vibrant and refreshing colour! It’s often associated with nature, growth, and harmony. Do you have a special reason why green is your favourite? 😊", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 51, 'prompt_tokens': 20, 'total_tokens': 71, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3-30b', 'system_fingerprint': 'vllm-0.22.1-a8343ffa', 'id': 'chatcmpl-9f4d223f5026065f', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4cfc-282a-72a3-8667-e2e2d7014092-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 20, 'output_tokens': 51, 'total_tokens': 71, 'input_token_details': {}, 'output_token_details': {}}),
#               HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='bd44d655-cd48-4fc0-b0dd-90ae532047e0'),
#               AIMessage(content="Hello Seán! 👋 It's great to meet you again—welcome back! Green is a fantastic choice—full of life, calm, and connection to nature. Whether it’s the lushness of forests, the freshness of spring, or even a favourite shirt or team jersey, green has a special way of standing out. Is there a particular shade of green you love most? 🌿💚", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 92, 'total_tokens': 174, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3-30b', 'system_fingerprint': 'vllm-0.22.1-a8343ffa', 'id': 'chatcmpl-ae374513e7e056af', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4d05-76cb-7912-9e06-4f79b5481641-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 92, 'output_tokens': 82, 'total_tokens': 174, 'input_token_details': {}, 'output_token_details': {}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='f34bbeac-2c9b-40ce-a787-9469cc2630a8'),
#               AIMessage(content='Your favourite colour is green, Seán! 🌿💚 You’ve mentioned it before, and it’s a wonderful choice—full of life, energy, and calm. It’s the colour of nature, growth, and balance. Do you have a favourite green thing—like a plant, a season, or even a lucky green item? 😊', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 72, 'prompt_tokens': 189, 'total_tokens': 261, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_provider': 'openai', 'model_name': 'qwen3-30b', 'system_fingerprint': 'vllm-0.22.1-a8343ffa', 'id': 'chatcmpl-9b39c8684463b58a', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f4d05-c15c-7d51-afde-f783cd0ae7f7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 189, 'output_tokens': 72, 'total_tokens': 261, 'input_token_details': {}, 'output_token_details': {}})]}
