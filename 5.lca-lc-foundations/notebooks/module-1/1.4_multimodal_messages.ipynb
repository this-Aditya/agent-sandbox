# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv
import os

from langchain.chat_models import init_chat_model

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

model = init_chat_model(
    model="arc:lite",
    model_provider="openai",
    base_url=os.getenv("RADAR_OPEN_MODEL_BASE_URL"),
    api_key=os.getenv("RADAR_OPEN_MODEL_API_KEY"),
)

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Since the Moon is currently a desolate, airless wasteland under international law, the answer depends on which "timeline" of human history you are inquiring about.
#
# As a science fiction writer, I will provide you with three distinct possibilities based on the genre of the future you wish to explore.
#
# ***
#
# ### 1. The High-Tech Utopia (The Solarpunk/Transhumanist Era)
# **Name:** **Selene Prime**
# **Location:** *The Mare Tranquillitatis (Sea of Tranquility)*
#
# Selene Prime is not a city of gray concrete, but a marvel of bio-engineering and light. Built within a massive, pressurized geodesic dome, the city resembles a sprawling, luminous jellyfish resting on the lunar dust.
#
# *   **Architecture:** The buildings are grown, not built, using lunar regolith fused with synthetic biological polymers. Towers curve like ivory tusks, shimmering with iridescent solar-collecting skins.
# *   **The Vibe:** It is a city of vertical gardens and hydroponic hanging forests. Since there is no natural wind, the city is silent, save for the soft hum of the air-scrubbers and the chime of gravity-manipulation transit pods.
# *   **Economy:** The seat of the *Lunar United Hegemony*, it serves as the primary hub for deep-space tourism and the refinement of Helium-3 for Earth’s energy needs.
#
# ### 2. The Industrial Grime (The Cyberpunk/Dystopian Era)
# **Name:** **Crater City (The Low-G Slums)**
# **Location:** *Tycho Crater*
#
# Forget the gleaming domes of the dreamers. Crater City is a claustrophobic, subterranean sprawl carved directly into the basalt walls of the Tycho crater. It is a city of shadows, neon, and recycled air.
#
# *   **Architecture:** Most of the "city" is actually a series of interconnected tunnels and modular shipping containers stacked precariously in low-gravity. Light is a luxury; the upper levels are bathed in harsh, artificial neon, while the lower levels live in a perpetual "artificial night."
# *   **The Vibe:** It smells of ozone, sweat, and recycled oxygen. It is a den of black-market tech-smuggling and asteroid-mining syndicates. If you want a neural-link upgrade or a stolen shipment of Martian spice, you come to the "Deep Rim" bars of Crater City.
# *   **Economy:** Raw extraction. The city exists to feed the hungry machines of the inner solar system. It is a gritty, high-stakes frontier town where life is cheap and the vacuum is always a single hairline fracture away.
#
# ### 3. The Ghost Frontier (The Post-Human/Archaeological Era)
# **Name:** **Aethelgard**
# **Location:** *The Far Side (The Lunar Dark)*
#
# In this timeline, the great expansion is long over. Earth is a myth, and the Moon is a tomb. Aethelgard is a "museum-city," a massive, sprawling complex of automated structures that continue to function without a single living soul.
#
# *   **Architecture:** Brutalist, monolithic, and grand. The structures are carved from the very crust of the Moon, designed to last for millions of years. It is a city of vast, empty plazas and silent, automated transit lines.
# *   **The Vibe:** Haunting and melancholic. The city is managed by "The Sentinels"—ancient, decaying AI-drones that still perform maintenance routines on a city that no longer has citizens. It is a monument to human ambition, left to run on solar cycles until the sun goes red.
# *   **Economy:** Non-existent. It is a relic of a vanished civilization, a ghost in the dark.
#
# ***
#
# **Which version of the Moon's capital shall we write about today? Or would you like me to forge a new one from the stardust?**

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'updated-interface.png', 'type': 'image/png', 'size': 668795, 'content': <memory at 0x10c564940>, 'last_modified': datetime.datetime(2026, 7, 10, 17, 58, 50, 279000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# The image you provided is a screenshot of a modern, data-driven health integration portal. To turn this into a science fiction capital city, I will reinterpret these "health data connections" as the literal, biological, and digital infrastructure of a sprawling megacity.
#
# Welcome to **The Nexus of Oura-Vera**, the capital of the Veridian Hegemony.
#
# ***
#
# ### **The Capital City: Oura-Vera (The Pulsing Spire)**
#
# In the year 2394, capital cities are no longer built of stone and steel alone; they are built of data, biometrics, and synchronized neural streams. **Oura-Vera** is the premier "Sentient Metropolis," a city that does not just house citizens, but *monitors* them to ensure total societal equilibrium.
#
# #### **1. The Architecture: The Layered Grid**
# Looking at the interface you provided, the city is organized into the **"Integration Tiers."** The architecture is modular and floating, held together by gravitational anchors.
# *   **The Fitbit Stratum (The Kinetic Lowlands):** The bottom level of the city is a hyper-active zone of movement. Massive, kinetic-energy-collecting pavements harvest the footsteps of millions. Every step taken by a citizen contributes to the city’s power grid. It is a place of constant motion, bright lights, and relentless physical optimization.
# *   **The Apple Core (The Central Neural Hub):** This is the polished, aesthetic center of the city. It is sleek, white, and seamless. Here, the biological and the digital are indistinguishable. The buildings have organic, curved shapes that pulse with a soft, rhythmic light, mimicking a heartbeat.
#
# #### **2. The Governing System: The "Google Health" Protocol**
# The city is not ruled by a king or a president, but by the **Central Sync Protocol (CSP)**.
#
# In Oura-Vera, "citizenship" is a real-time connection. To live in the capital, you must undergo the **Connection Sequence**. As seen in your screenshot, the city requires a "Successful Connection" to function. Upon arrival, your neural lace, heart rate, sleep cycles, and even your blood oxygen levels are integrated into the city’s mainframe.
#
# *   **The Social Contract:** In exchange for total physiological optimization (the city can predict a heart attack before it happens or adjust the oxygen levels in your hab-unit to ensure perfect sleep), you grant the city "Read-Only Access" to your biological signature.
# *   **The Data Currency:** Your "Activity & Fitness" aren't just personal stats; they are the city's fuel. A citizen with high "Sleep Stability" and "Heart Health" is granted higher tier access to the upper spires.
#
# #### **3. The "Huawei" Outskirts (The Peripheral Buffer)**
# On the edges of the city lie the **Huawei Fringe**, a jagged, industrial zone that manages the heavy lifting of the city’s logistics. It is less "perfect" than the Apple Core, characterized by rapid-fire data transmission and massive, clunky automated refineries that process the raw biological data of the masses into usable energy.
#
# #### **4. The Atmosphere: The Blue Glare**
# The sky over Oura-Vera is never truly dark. It is a constant, shimmering shade of **"Interface Blue."** Holographic displays float in the air, showing the city's "Vital Signs." If the city’s collective heart rate rises too high (perhaps due to a protest or a localized crisis), the sky shifts to a warning amber, signaling the CSP to deploy "Stabilization Units."
#
# #### **The Conflict: The "Disconnected"**
# The dark underside of this beautiful, optimized capital is the fear of the **"Timeout."** To be disconnected from the central hub is to become a ghost. Those who cannot—or will not—connect their biological data are exiled to the dead zones outside the city walls, where the data doesn't reach, and the "Heartbeat" of the city cannot save them.
#
# ***
#
# **"Your vitality is our stability. Thank you for connecting to the Hegemony."**

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.53it/s]
# Done.

# %%
agent = create_agent(
    model=model,
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[21], line 10
#       1 agent = create_agent(
#       2     model=model,
#       3 )
#       5 multimodal_question = HumanMessage(content=[
#       6     {"type": "text", "text": "Tell me about this audio file"},
#       7     {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
#       8 ])
# ---> 10 response = agent.invoke(
#      11     {"messages": [multimodal_question]}
#      12 )
#      14 print(response['messages'][-1].content)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:3928, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, version, **kwargs)
#    3925             chunks.append(chunk)
#    3926 else:
#    3927     # v1: collect interrupts from updates stream
# -> 3928     for chunk in self.stream(
#    3929         input,
#    3930         config,
#    3931         context=context,
#    3932         stream_mode=(
#    3933             ["updates", "values"] if stream_mode == "values" else stream_mode
#    3934         ),
#    3935         print_mode=print_mode,
#    3936         output_keys=output_keys,
#    3937         interrupt_before=interrupt_before,
#    3938         interrupt_after=interrupt_after,
#    3939         durability=durability,
#    3940         control=control,
#    3941         **kwargs,
#    3942     ):
#    3943         if stream_mode == "values":
#    3944             if len(chunk) == 2:
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/main.py:2982, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2980 for task in loop.match_cached_writes():
#    2981     loop.output_writes(task.id, task.writes, cached=True)
# -> 2982 for _ in runner.tick(
#    2983     [t for t in loop.tasks.values() if not t.writes],
#    2984     timeout=self.step_timeout,
#    2985     get_waiter=get_waiter,
#    2986     schedule_task=loop.accept_push,
#    2987 ):
#    2988     # emit output
#    2989     yield from _output(
#    2990         stream_mode,
#    2991         print_mode,
#    (...)   2997         _state_mapper,
#    2998     )
#    2999 loop.after_tick()
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/pregel/_retry.py:617, in run_with_retry(task, retry_policy, configurable)
#     615     task.writes.clear()
#     616     # run the task
# --> 617     return task.proc.invoke(task.input, config)
#     618 except ParentCommand as exc:
#     619     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langgraph/_internal/_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1421, in create_agent.<locals>.model_node(state, runtime)
#    1409 request = ModelRequest(
#    1410     model=model,
#    1411     tools=default_tools,
#    (...)   1417     runtime=runtime,
#    1418 )
#    1420 if wrap_model_call_handler is None:
# -> 1421     model_response = _execute_model_sync(request)
#    1422     return _build_commands(model_response)
#    1424 result = wrap_model_call_handler(request, _execute_model_sync)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain/agents/factory.py:1393, in create_agent.<locals>._execute_model_sync(request)
#    1390 if request.system_message:
#    1391     messages = [request.system_message, *messages]
# -> 1393 output = model_.invoke(messages)
#    1394 if name:
#    1395     output.name = name
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/runnables/base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1501, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1499         response = raw_response.parse()
#    1500 except openai.BadRequestError as e:
# -> 1501     _handle_openai_bad_request(e)
#    1502 except openai.APIError as e:
#    1503     _handle_openai_api_error(e)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1498, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1491         return _construct_lc_result_from_responses_api(
#    1492             response,
#    1493             schema=original_schema_obj,
#    1494             metadata=generation_info,
#    1495             output_version=self.output_version,
#    1496         )
#    1497     else:
# -> 1498         raw_response = self.client.with_raw_response.create(**payload)
#    1499         response = raw_response.parse()
#    1500 except openai.BadRequestError as e:
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1211, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1164 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1165 def create(
#    1166     self,
#    (...)   1208     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1209 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1210     validate_response_format(response_format)
# -> 1211     return self._post(
#    1212         "/chat/completions",
#    1213         body=maybe_transform(
#    1214             {
#    1215                 "messages": messages,
#    1216                 "model": model,
#    1217                 "audio": audio,
#    1218                 "frequency_penalty": frequency_penalty,
#    1219                 "function_call": function_call,
#    1220                 "functions": functions,
#    1221                 "logit_bias": logit_bias,
#    1222                 "logprobs": logprobs,
#    1223                 "max_completion_tokens": max_completion_tokens,
#    1224                 "max_tokens": max_tokens,
#    1225                 "metadata": metadata,
#    1226                 "modalities": modalities,
#    1227                 "n": n,
#    1228                 "parallel_tool_calls": parallel_tool_calls,
#    1229                 "prediction": prediction,
#    1230                 "presence_penalty": presence_penalty,
#    1231                 "prompt_cache_key": prompt_cache_key,
#    1232                 "prompt_cache_retention": prompt_cache_retention,
#    1233                 "reasoning_effort": reasoning_effort,
#    1234                 "response_format": response_format,
#    1235                 "safety_identifier": safety_identifier,
#    1236                 "seed": seed,
#    1237                 "service_tier": service_tier,
#    1238                 "stop": stop,
#    1239                 "store": store,
#    1240                 "stream": stream,
#    1241                 "stream_options": stream_options,
#    1242                 "temperature": temperature,
#    1243                 "tool_choice": tool_choice,
#    1244                 "tools": tools,
#    1245                 "top_logprobs": top_logprobs,
#    1246                 "top_p": top_p,
#    1247                 "user": user,
#    1248                 "verbosity": verbosity,
#    1249                 "web_search_options": web_search_options,
#    1250             },
#    1251             completion_create_params.CompletionCreateParamsStreaming
#    1252             if stream
#    1253             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1254         ),
#    1255         options=make_request_options(
#    1256             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1257         ),
#    1258         cast_to=ChatCompletion,
#    1259         stream=stream or False,
#    1260         stream_cls=Stream[ChatCompletionChunk],
#    1261     )
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1288     warnings.warn(
#    1289         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1290         "Please pass raw bytes via the `content` parameter instead.",
#    1291         DeprecationWarning,
#    1292         stacklevel=2,
#    1293     )
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Partition/Projects/agent-sandbox/5.lca-lc-foundations/.venv/lib/python3.13/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1067             err.response.read()
#    1069         log.debug("Re-raising status error")
# -> 1070         raise self._make_status_error_from_response(err.response) from None
#    1072     break
#    1074 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'litellm.BadRequestError: Hosted_vllmException - {"error":{"message":"Audio input was provided but the model \'RedHatAI/gemma-4-26B-A4B-it-NVFP4\' does not have an audio tower. Audio inference is only supported for Gemma4 models that include an audio_config (i.e., models that include an audio_config).","type":"BadRequestError","param":null,"code":400}}. Received Model Group=arc:lite\nAvailable Model Group Fallbacks=None', 'type': None, 'param': None, 'code': '400'}}
# During task with name 'model' and id 'b27aac48-44f2-4e30-38b3-5a885be58c45'
